# %% [markdown]
# # check environment

# %%
import os
os.environ["OMP_NUM_THREADS"] = "3" # export OMP_NUM_THREADS=4
os.environ["OPENBLAS_NUM_THREADS"] = "3" # export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = "4" # export MKL_NUM_THREADS=6
os.environ["VECLIB_MAXIMUM_THREADS"] = "3" # export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = "4" # export NUMEXPR_NUM_THREADS=6

import sys
import pprint
pprint.pprint(sys.path)


import torch
print(torch.__version__)

import torch

if torch.cuda.is_available():
    print("CUDAが利用可能です")
    print("CUDAバージョン:", torch.version.cuda)
else:
    print("CUDAは利用できません")


ddp = int(os.environ.get('RANK', -1)) != -1 # is this a ddp run?
print("ddp", ddp, os.environ.get('RANK', -1))

# args_annotations = Myclass.init.annotations
# for arg, annotation in args_annotations.items():
#      print(f"Argument: {arg}, Type: {annotation}")

# try how to enable ddp
osenv_keys = os.environ.keys()
for key in osenv_keys:
    print("key =", key)
    print(os.environ[key])
    print("\n")
# Out:
# ['/home/kan/ML_appliaction/Transformer_dir',
#  '/home/kan/.pyenv/versions/anaconda3-2023.03-1/envs/torch-gpu/lib/python39.zip',
#  '/home/kan/.pyenv/versions/anaconda3-2023.03-1/envs/torch-gpu/lib/python3.9',
#  '/home/kan/.pyenv/versions/anaconda3-2023.03-1/envs/torch-gpu/lib/python3.9/lib-dynload',
#  '',
#  '/home/kan/.pyenv/versions/anaconda3-2023.03-1/envs/torch-gpu/lib/python3.9/site-packages']
# 1.8.1
# CUDAが利用可能です
# CUDAバージョン: 11.1
# ddp False -1
# key = USER
# kan
#
#
# key = SSH_CLIENT
# 172.25.173.0 52137 22
#
#
# key = XDG_SESSION_TYPE
# tty
#
#
# key = SHLVL
# 1
#
#
# key = MOTD_SHOWN
# pam
#
#
# key = HOME
# /home/kan
#
#
# key = DBUS_SESSION_BUS_ADDRESS
# unix:path=/run/user/1006/bus
#
#
# key = LOGNAME
# kan
#
#
# key = _
# /home/kan/.pyenv/versions/anaconda3-2023.03-1/envs/torch-gpu/bin/python
#
#
# key = XDG_SESSION_CLASS
# user
#
#
# key = XDG_SESSION_ID
# 9085
#
#
# key = PATH
# ...
